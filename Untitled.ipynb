# %%
import pandas as pd

# %%
spawn = pd.read_csv("spawns.csv")

# %%
spawn[spawn['Map'] == 'Route 111 Desert']
# Out:
#       Unnamed: 0               Map    Pokemon  DexID  MinLvl  MaxLvl  \
# 2756        2756  Route 111 Desert     Baltoy    343      20      24
# 2757        2757  Route 111 Desert     Cacnea    331      20      24
# 2758        2758  Route 111 Desert   Cacturne    332      20      24
# 2759        2759  Route 111 Desert    Diglett     50      20      24
# 2760        2760  Route 111 Desert   Maractus    556      20      24
# 2761        2761  Route 111 Desert   Nosepass    299      20      24
# 2762        2762  Route 111 Desert    Sandile    551      20      24
# 2763        2763  Route 111 Desert  Sandshrew     27      20      24
# 2764        2764  Route 111 Desert   Trapinch    328      25      29
#
#                Item    Member      Tier  Type  ...    Time  Level   base_map  \
# 2756            NaN       NaN  Uncommon  Land  ...  M/D/Ni  20-24  Route 111
# 2757    Sticky Barb       NaN    Common  Land  ...  M/D/Ni  20-24  Route 111
# ...
